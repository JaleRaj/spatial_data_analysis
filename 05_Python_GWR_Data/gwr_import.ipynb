# %% [markdown]
# # Preparation of GWR - Data

# %% [markdown]
# ## Libraries and Settings

# %%
# Libraries
import os
import json
import folium
import requests
import numpy as np
import pandas as pd
import geopandas as gpd
from datetime import date

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

print(os.getcwd())
# Out:
# /workspaces/spatial_data_analysis/05_Python_GWR_Data

# %% [markdown]
# ## Download GWR data
#
# Source: https://public.madd.bfs.admin.ch

# %%
# Download latest file for the Canton of Zurich
url = "https://public.madd.bfs.admin.ch/buildings_ow.geojson"
response = requests.get(url)

# Ensure response is valid
if response.status_code == 200:
    # Open file in write mode and write the response content
    with open('buildings_zh.geojson', 'wb') as file:
        file.write(response.content)
else:
    print(f"Failed to download file, status code: {response.status_code}")

# %% [markdown]
# ## Import latest GWR Data

# %%
# Load json file
with open('buildings_zh.geojson') as f:
    data = json.load(f)

# Flatten nested json data
df_orig = pd.json_normalize(data, record_path=['features'])
df_orig

# Remove prefix
df_orig.columns = df_orig.columns.str.replace('properties.', '')
df_orig.columns = df_orig.columns.str.replace('geometry.', '')

# Create copy
df = df_orig.copy()
df.head()
# Out:
#       type       egid  buildingStatus  buildingCategory  buildingClass  \
# 0  Feature  101235305            1007              1020           1110
# 1  Feature  101235307            1004              1020           1110
# 2  Feature  101235308            1004              1020           1122
# 3  Feature  101235310            1004              1020           1110
# 4  Feature  101235311            1004              1020           1110
#
#    municipalityNumber municipalityName canton   type  \
# 0                1401          Alpnach     OW  Point
# 1                1401          Alpnach     OW  Point
# 2                1401          Alpnach     OW  Point
# 3                1401          Alpnach     OW  Point
# 4                1401          Alpnach     OW  Point
#
#                   coordinates
# 0          [2662391, 1198346]
# 1  [2662273.495, 1198664.438]
# 2  [2663069.775, 1200010.861]
# 3  [2662170.316, 1198226.835]
# 4  [2662135.736, 1198271.709]

# %% [markdown]
# ## Separate Swiss LV95 coordinates

# %%
# Separate coordinates
df['x_coords'] = pd.DataFrame(df['coordinates'].tolist(), columns=['x_coord', 'y_coord'])['x_coord']
df['y_coords'] = pd.DataFrame(df['coordinates'].tolist(), columns=['x_coord', 'y_coord'])['y_coord']

# Remove column 'coordinates'
df = df.drop(['coordinates'], axis=1)
df
# Out:
#           type       egid  buildingStatus  buildingCategory  buildingClass  \
# 0      Feature  101235305            1007              1020           1110
# 1      Feature  101235307            1004              1020           1110
# 2      Feature  101235308            1004              1020           1122
# 3      Feature  101235310            1004              1020           1110
# 4      Feature  101235311            1004              1020           1110
# ...        ...        ...             ...               ...            ...
# 21923  Feature    9082198            1004              1040              0
# 21924  Feature    9082200            1004              1060              0
# 21925  Feature    9082201            1004              1060              0
# 21926  Feature    9082202            1004              1060              0
# 21927  Feature    9082205            1004              1060              0
#
#        municipalityNumber municipalityName canton   type     x_coords  \
# 0                    1401          Alpnach     OW  Point  2662391.000
# 1                    1401          Alpnach     OW  Point  2662273.495
# 2                    1401          Alpnach     OW  Point  2663069.775
# 3                    1401          Alpnach     OW  Point  2662170.316
# 4                    1401          Alpnach     OW  Point  2662135.736
# ...                   ...              ...    ...    ...          ...
# 21923                1407           Sarnen     OW  Point  2661576.416
# 21924                1407           Sarnen     OW  Point  2661535.114
# 21925                1407           Sarnen     OW  Point  2661735.402
# 21926                1407           Sarnen     OW  Point  2661570.119
# 21927                1407           Sarnen     OW  Point  2662284.807
#
#           y_coords
# 0      1198346.000
# 1      1198664.438
# 2      1200010.861
# 3      1198226.835
# 4      1198271.709
# ...            ...
# 21923  1194345.086
# 21924  1194255.211
# 21925  1194681.900
# 21926  1194122.619
# 21927  1195193.426
#
# [21928 rows x 11 columns]

# %% [markdown]
# ## Create WGS84 coordinates

# %%
# Create geodataframe and calculate latitude and longitude
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['x_coords'], df['y_coords']), crs="EPSG:2056")

# Convert the Swiss LV95 coordinates to lat & lon
gdf = gdf.to_crs(epsg=4326)

# Get Latitude and Longitude
df['latitude'] = gdf['geometry'].y
df['longitude'] = gdf['geometry'].x

# Show data
df
# Out:
#           type       egid  buildingStatus  buildingCategory  buildingClass  \
# 0      Feature  101235305            1007              1020           1110
# 1      Feature  101235307            1004              1020           1110
# 2      Feature  101235308            1004              1020           1122
# 3      Feature  101235310            1004              1020           1110
# 4      Feature  101235311            1004              1020           1110
# ...        ...        ...             ...               ...            ...
# 21923  Feature    9082198            1004              1040              0
# 21924  Feature    9082200            1004              1060              0
# 21925  Feature    9082201            1004              1060              0
# 21926  Feature    9082202            1004              1060              0
# 21927  Feature    9082205            1004              1060              0
#
#        municipalityNumber municipalityName canton   type     x_coords  \
# 0                    1401          Alpnach     OW  Point  2662391.000
# 1                    1401          Alpnach     OW  Point  2662273.495
# 2                    1401          Alpnach     OW  Point  2663069.775
# 3                    1401          Alpnach     OW  Point  2662170.316
# 4                    1401          Alpnach     OW  Point  2662135.736
# ...                   ...              ...    ...    ...          ...
# 21923                1407           Sarnen     OW  Point  2661576.416
# 21924                1407           Sarnen     OW  Point  2661535.114
# 21925                1407           Sarnen     OW  Point  2661735.402
# 21926                1407           Sarnen     OW  Point  2661570.119
# 21927                1407           Sarnen     OW  Point  2662284.807
#
#           y_coords   latitude  longitude
# 0      1198346.000  46.933279   8.257952
# 1      1198664.438  46.936154   8.256452
# 2      1200010.861  46.948190   8.267095
# 3      1198226.835  46.932228   8.255038
# 4      1198271.709  46.932635   8.254590
# ...            ...        ...        ...
# 21923  1194345.086  46.897368   8.246714
# 21924  1194255.211  46.896563   8.246160
# 21925  1194681.900  46.900383   8.248846
# 21926  1194122.619  46.895367   8.246602
# 21927  1195193.426  46.904933   8.256126
#
# [21928 rows x 13 columns]

# %% [markdown]
# ## Plot subset of buildings

# %%
# Subset
df_sub = df.loc[df['municipalityName'] == 'Kerns'].sample(100).dropna()
df_sub

# Create the map
m = folium.Map(location=[df_sub['latitude'].mean(), df_sub['longitude'].mean()], zoom_start=15)

# Add points to the map
for idx, row in df_sub.iterrows():
    folium.Marker(location=([row['latitude'], 
                            row['longitude']]),
                  popup=row['buildingCategory']).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_72069803cb9eb66c546ef08b1ac528d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_72069803cb9eb66c546ef08b1ac528d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_72069803cb9eb66c546ef08b1ac528d5 = L.map(
#                 &quot;map_72069803cb9eb66c546ef08b1ac528d5&quot;,
#                 {
#                     center: [46.88295194958194, 8.282686080622264],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb66f376cb1ff3c753103253a140d188 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cb66f376cb1ff3c753103253a140d188.addTo(map_72069803cb9eb66c546ef08b1ac528d5);
#
#
#             var marker_891c70ed60eb19a90e3c169f2f3fcf38 = L.marker(
#                 [46.898060953726784, 8.272437375506458],
#                 {}
#             ).addTo(map_72069803cb9eb66c546ef08b1ac528d5);
#
#
#         var popup_5d27c97a4daa72f16ff02d28aa2e51a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_865c1d1c1abca2c0febe032b99e863fb = $(`&lt;div id=&quot;html_865c1d1c1abca2c0febe032b99e863fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1020&lt;/div&gt;`)[0];
#                 popup_5d27c97a4daa72f16ff02d28aa2e51a8.setContent(html_865c1d1c1abca2c0febe032b99e863fb);
#
#
#
#         marker_891c70ed60eb19a90e3c169f2f3fcf38.bindPopup(popup_5d27c97a4daa72f16ff02d28aa2e51a8)
#         ;
#
#
#
#
#             var marker_66ae405830765e8d3bab637d7a0b2909 = L.marker(
#                 [46.900540913423725, 8.268821922910462],
#                 {}
#             ).addTo(map_72069803cb9eb66c546ef08b1ac528d5);
#
#
#         var popup_4f2554177e353d4facab1d594cc1c69c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cc9175f542bc11c0b902e5024b3e495e = $(`&lt;div id=&quot;html_cc9175f542bc11c0b902e5024b3e495e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1020&lt;/div&gt;`)[0];
#                 popup_4f2554177e353d4facab1d594cc1c69c.setContent(html_cc9175f542bc11c0b902e5024b3e495e);
#
#
#
#         marker_66ae405830765e8d3bab637d7a0b2909.bindPopup(popup_4f2554177e353d4facab1d594cc1c69c)
#         ;
#
#
#
#
#             var marker_d0749ce3fa56a39c51dcaa4c4201ba6e = L.marker(
#                 [46.906948884439764, 8.275206763070425],
#                 {}
#             ).addTo(map_72069803cb9eb66c546ef08b1ac528d5);
#
#
#         var popup_1ed138e4d325034176191afc18b373bb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_02f927474dc181595d5548d5ec633ef6 = $(`&lt;div id=&quot;html_02f927474dc181595d5548d5ec633ef6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1060&lt;/div&gt;`)[0];
#                 popup_1ed138e4d325034176191afc18b373bb.setContent(html_02f927474dc181595d5548d5ec633ef6);
#
#
#
#         marker_d0749ce3fa56a39c51dcaa4c4201ba6e.bindPopup(popup_1ed138e4d325034176191afc18b373bb)
#         ;
#
#
#
#
#             var marker_b103c2e8e79b0174a5e28c770144c6aa = L.marker(
#                 [46.9089191300011, 8.293355768884306],
#                 {}
#             ).addTo(map_72069803cb9eb66c546ef08b1ac528d5);
#
#
#         var popup_fa8859013b7854201b878de8bfe3ab31 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ed740cc44884ab752611f58cc1d1550 = $(`&lt;div id=&quot;html_4ed740cc44884ab752611f58cc1d1550&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1060&lt;/div&gt;`)[0];
#                 popup_fa8859013b7854201b878de8bfe3ab31.setContent(html_4ed740cc44884ab752611f58cc1d1550);
#
#
#
#         marker_b103c2e8e79b0174a5e28c770144c6aa.bindPopup(popup_fa8859013b7854201b878de8bfe3ab31)
#         ;
#
#
#
#
#             var marker_389faa629521efe478c1a5cdfef31196 = L.marker(
#                 [46.90638063948293, 8.274855890098792],
#                 {}
#             ).addTo(map_72069803cb9eb66c546ef08b1ac528d5);
#
#
#         var popup_71bac9fcdcdefef712aa61b2c42c6d76 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e2bf9a59c0255c158425d8f301832d03 = $(`&lt;div id=&quot;html_e2bf9a59c0255c158425d8f301832d03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1060&lt;/div&gt;`)[0];
#                 popup_71bac9fcdcdefef712aa61b2c42c6d76.setContent(html_e2bf9a59c0255c158425d8f301832d03);
#
#
#
#         marker_389faa629521efe478c1a5cdfef31196.bindPopup(popup_71bac9fcdcdefef712aa61b2c42c6d76)
#         ;
#
#
#
#
#             var marker_e602a131b024f20c7d8a4a41d7c5db08 = L.marker(
#                 [46.90066098635058, 8.267483511919698],

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.2.0-1019-azure
# Datetime: 2024-03-12 20:32:21
# Python Version: 3.10.13
# -----------------------------------
